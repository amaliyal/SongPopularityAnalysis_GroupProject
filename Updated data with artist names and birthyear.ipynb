# %%
import pandas as pd
df = pd.read_csv('track_artist_audio_features_cleaned.csv')

# %%
df
# Out:
#                                                    song  \
# 0                                      ...Ready For It?
# 1                                          Life Changes
# 2                                             24K Magic
# 3                                           Galway Girl
# 4                                            Photograph
# ...                                                 ...
# 7664                       Alice's Restaurant Massacree
# 7665                         Remember the Future, Pt. 1
# 7666  Funeral For A Friend / Love Lies Bleeding - Re...
# 7667                                    Fool's Overture
# 7668               Heart of the Sunrise - 2003 Remaster
#
#                     track_id release_date  song_popularity  duration(ms)  \
# 0     2yLa0QULdQr0qAIvVwN6B5   2017-11-10               74        208186
# 1     4Vxu50qVrQcycjRyJQaZLC   2017-09-08               65        190226
# ...

# %%
df_ = df.copy()

# %%
df_
# Out:
#                                                    song  \
# 0                                      ...Ready For It?
# 1                                          Life Changes
# 2                                             24K Magic
# 3                                           Galway Girl
# 4                                            Photograph
# ...                                                 ...
# 7664                       Alice's Restaurant Massacree
# 7665                         Remember the Future, Pt. 1
# 7666  Funeral For A Friend / Love Lies Bleeding - Re...
# 7667                                    Fool's Overture
# 7668               Heart of the Sunrise - 2003 Remaster
#
#                     track_id release_date  song_popularity  duration(ms)  \
# 0     2yLa0QULdQr0qAIvVwN6B5   2017-11-10               74        208186
# 1     4Vxu50qVrQcycjRyJQaZLC   2017-09-08               65        190226
# ...

# %%
# df['column name'] = df['column name'].str.replace('old character','new character')
df_['artist_name'] = df_['artist_name'].str.replace('$','S')
# Out:
# C:\Users\hemsl\AppData\Local\Temp\ipykernel_26520\873619319.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_['artist_name'] = df_['artist_name'].str.replace('$','S')

# %%
new = list(df_['artist_name'].unique())
# new.sort(reverse=True)
new.sort()
new = list(pd.Series(new).str.strip())

# %%
new[2000:]
# Out:
# ['My Chemical Romance Piano Tribute',
#  'My Epic',
#  'My Favorite Highway',
#  'My Life With The Thrill Kill Kult',
#  'My Morning Jacket',
#  'My Sun and Stars',
#  'Mystery Skulls',
#  'MÖWE',
#  'MØ',
#  'Mørk',
#  'N.W.A.',
#  'NCT 127',
#  'NEEDTOBREATHE',
#  'NEFFEX',
#  'NERO',
#  'NF',
#  'NONONO',
#  'NSYNC',
#  'Nabihah Iqbal',
#  'Nada Surf',
#  'Naked Eyes',
#  'Nana Twice & DubJay',
#  'Nancy Sinatra',
#  'Nappy Roots',
#  'Nat & Alex Wolff',
#  'Nat King Cole',
#  'Nat King Cole Trio',
#  'Natalie Imbruglia',
#  'Natalie Kelsea',
#  'Natalie Marchenko',
#  'Natalie Merchant',
#  'Natasha Bedingfield',
#  'Natasha Mosley',
#  'NateWantsToBattle',
#  'Nathan Sykes',
#  'Natt Rodríguez',
#  'Natural White Noise for Babies',
#  'Nature Sounds',
#  'Nature Sounds - Sons de la nature',
#  'Ne-Yo',
#  'Neck Deep',
#  'Neil Diamond',
#  'Neil Young',
#  'Nektar',
#  'Neku',
#  'Nelly',
#  'Nelly Furtado',
#  'Nelson May',
#  'Nena',
#  'Neon Trees',
#  'Neutral Milk Hotel',
# ...

# %%
[*, ]

# %%
'Ateez' in list(df['artist_name'].unique())
# Out:
# True

# %%
df[df['artist_name']=='P!nk']
# Out:
#                       song                track_id release_date  \
# 361          What About Us  0Qh38w01QRXK6KHIv0e3hb   2017-10-13
# 757                So What  0JiY190vktuhSGN6aqJdrt   2008-10-24
# 1765      Raise Your Glass  1gv4xPanImH17bKZ9rOveR   2010-10-05
# 1781                 Sober  733ncRLzZQT5UtSPg1QmPc   2008-10-24
# 2080      A Million Dreams  0oagwWkGlBoACUuKvTmqZV   2018-10-24
# 3279  The Truth About Love  2bq6lTZcVtQ6m8bpaVCwA9   2012-09-18
# 5844          Walk Me Home  7DHApOHsIFo7EyfieArYGE   2019-02-20
#
#       song_popularity  duration(ms)  explicit artist_name  \
# 361                74        269600     False        P!nk
# 757                77        215160      True        P!nk
# 1765               77        202960      True        P!nk
# 1781               64        251533     False        P!nk
# 2080               66        273640     False        P!nk
# 3279               44        228466      True        P!nk
# ...

# %%
#had to use this replace method to update several artist names to match the way they appear on wikipedia
df_['artist_name'].replace(to_replace =['scntfc'],
                 value ='Scntfc', inplace = True)

# %%
df_.to_csv('track artist audio features cleaned.csv')
df_[df_['artist_name'] == 'Pink_(singer)']
# Out:
#                       song                track_id release_date  \
# 361          What About Us  0Qh38w01QRXK6KHIv0e3hb   2017-10-13
# 757                So What  0JiY190vktuhSGN6aqJdrt   2008-10-24
# 1765      Raise Your Glass  1gv4xPanImH17bKZ9rOveR   2010-10-05
# 1781                 Sober  733ncRLzZQT5UtSPg1QmPc   2008-10-24
# 2080      A Million Dreams  0oagwWkGlBoACUuKvTmqZV   2018-10-24
# 3279  The Truth About Love  2bq6lTZcVtQ6m8bpaVCwA9   2012-09-18
# 5844          Walk Me Home  7DHApOHsIFo7EyfieArYGE   2019-02-20
#
#       song_popularity  duration(ms)  explicit    artist_name  \
# 361                74        269600     False  Pink_(singer)
# 757                77        215160      True  Pink_(singer)
# 1765               77        202960      True  Pink_(singer)
# 1781               64        251533     False  Pink_(singer)
# 2080               66        273640     False  Pink_(singer)
# 3279               44        228466      True  Pink_(singer)
# ...

# %%
df_.loc[7366]
# Out:
# song                  HALA HALA (Hearts Awakened, Live Alive)
# track_id                               4v2BLMhWtVvBnZwuoiKxja
# release_date                                       2019-01-15
# song_popularity                                            60
# duration(ms)                                           202097
# explicit                                                False
# artist_name                                             Ateez
# artist_id                              68KmkJeZGfwe1OUaivBa2L
# artist_follower_no                                    2407024
# artist_genres                    ['k-pop', 'k-pop boy group']
# artist_popularity                                          68
# acousticness                                           0.0153
# danceability                                            0.572
# energy                                                  0.778
# instrumentalness                                          0.0
# ...

# %%
list(df_['artist_name'].unique())
# Out:
# ['Taylor Swift',
#  'Thomas Rhett',
#  'Bruno Mars',
#  'Ed Sheeran',
#  'Bill Conti',
#  'Neon Trees',
#  'Maroon 5',
#  'Sugarland',
#  'Billboard Top 100 Hits',
#  'Khalid',
#  'Natasha Bedingfield',
#  'R. Kelly',
#  'Tom Petty',
#  'Van Morrison',
#  'Jason Derulo',
#  'Train',
#  'Portugal. The Man',
#  'Justin Timberlake',
#  'Katy Perry',
#  'Village People',
#  'The Killers',
#  'DNCE',
#  'Carly Rae Jepsen',
#  'John Legend',
#  'Loose Passenger Seat',
#  'Sam Smith',
#  'Justin Bieber',
#  'Demi Lovato',
#  'Kelly Clarkson',
#  'Brett Young',
#  'Jordan Davis',
#  'Devin Dawson',
#  'Luke Bryan',
#  'Blake Shelton',
#  'LANCO',
#  'Walker Hayes',
#  'Morgan Evans',
#  'Brett Eldredge',
#  'Jackie Lee',
#  'Billy Currington',
#  'Granger Smith',
#  'Brett Kissel',
#  'Outkast Tribute Band',
#  'Miley Cyrus',
#  'Becky G',
#  'Iyaz',
#  'Taio Cruz',
#  'Black Eyed Peas',
#  'fun.',
#  'Rupert Holmes',
#  'Colbie Caillat',
#  'Neil Diamond',
#  "The B-52's",
# ...

# %%
art = pd.read_excel('artists_details with id.xlsx')
art
# Out:
#                                                  names  \
# 0                                         Taylor Swift
# 1                                         Thomas Rhett
# 2                                           Bruno Mars
# 3                                           Ed Sheeran
# 4                                           Bill Conti
# ...                                                ...
# 2100                                              Got7
# 2101                                               Exo
# 2102                                            J-Hope
# 2103  The Rise and Fall of Bossanova (A 13:23:32 Song)
# 2104                                     Banco de Gaia
#
#                                                 members  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# ...

# %%
art_['Date_']=art_['birth_date'].str.extract(r'(\d{4})')
art_
# Out:
#                                                  names  \
# 0                                         Taylor Swift
# 1                                         Thomas Rhett
# 2                                           Bruno Mars
# 3                                           Ed Sheeran
# 4                                           Bill Conti
# ...                                                ...
# 2100                                              Got7
# 2101                                               Exo
# 2102                                            J-Hope
# 2103  The Rise and Fall of Bossanova (A 13:23:32 Song)
# 2104                                     Banco de Gaia
#
#                                                 members  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# ...

# %%
art_.rename(columns={'Date_':'birth_year'}, inplace = True)

# %%
art_.to_csv('artist_details_with_id.csv',index=False )

# %%
d = pd.read_csv('artist_details_with_id.csv')
d
# Out:
#                                                  names  \
# 0                                         Taylor Swift
# 1                                         Thomas Rhett
# 2                                           Bruno Mars
# 3                                           Ed Sheeran
# 4                                           Bill Conti
# ...                                                ...
# 2100                                              Got7
# 2101                                               Exo
# 2102                                            J-Hope
# 2103  The Rise and Fall of Bossanova (A 13:23:32 Song)
# 2104                                     Banco de Gaia
#
#                                                 members  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# ...
