# %%
import pandas as pd

# %%
# artist = pd.read_excel('artists_details with id.xlsx')
# artist.head()
# Out:
#           names members                  birth_name  \
# 0  Taylor Swift     NaN         Taylor Alison Swift
# 1  Thomas Rhett     NaN      Thomas Rhett Akins Jr.
# 2    Bruno Mars     NaN        Peter Gene Hernandez
# 3    Ed Sheeran     NaN  Edward Christopher Sheeran
# 4    Bill Conti     NaN               William Conti
#
#                             birth_place  \
# 0  [[West Reading, Pennsylvania]], U.S.
# 1        [[Nashville, Tennessee]], U.S.
# 2   [[Honolulu|Honolulu, Hawaii]], U.S.
# 3  [[Halifax, West Yorkshire]], England
# 4    [[Providence, Rhode Island]], U.S.
#
#                                 birth_date  gender  \
# 0        {{Birth date and age|1989|12|13}}  female
# 1        {{birth date and age|1990|03|30}}    male
# 2        {{birth date and age|1985|10|08}}    male
# 3  {{Birth date and age|df|=|y|1991|2|17}}    male
# 4         {{Birth date and age|1942|4|13}}    male
#
#                            category spotify track artist audio.artist_name  \
# ...

# %%
artist.isnull().sum()
# Out:
# names                                       79
# members                                   1313
# birth_name                                1223
# birth_place                                101
# birth_date                                1061
# gender                                    1327
# category                                  1514
# spotify track artist audio.artist_name     321
# spotify track artist audio.artist_id       321
# dtype: int64

# %%
artist[artist['gender'].isnull()].head(20)
# Out:
#                      names                                            members  \
# 365            Silverchair                                                NaN
# 366              Semisonic  * [[John Munson]]\n* [[Jacob Slichter]]\n* [[D...
# 367            Soundgarden                                                NaN
# 368          The Offspring  * [[Dexter Holland]]\n* [[Noodles (musician)|N...
# 369                   Korn  * [[Jonathan Davis]]\n* [[James Shaffer]]\n* [...
# 370    Stone Temple Pilots  * [[Dean DeLeo]]\n* [[Robert DeLeo]]\n* [[Eric...
# 371            Blind Melon  * [[Rogers Stevens]]\n* Christopher Thorn\n* G...
# 372  The Smashing Pumpkins  * [[Billy Corgan]]\n* [[James Iha]]\n* [[Jimmy...
# 374                Wheatus  Brendan B. Brown<br>Matthew Milligan<br>Brando...
# 375              Nine Days  John Hampson<br />Brian Desveaux<br />Jeremy D...
# 376              Everclear                                                NaN
# ...

# %%
artist.loc[[], 'gender'] = 'male'
artist.loc[[], 'gender'] = 'female'
artist.loc[[], 'gender'] = 'male, female'

# not artists or duplicates
# artist.drop([98, 196, 197, 238, 253, 2093, 2097, 2103], inplace=True)
# artist.drop([299, 307], inplace=True)


# artist.loc[[336, 338, 339, 342, 351, 355, 358, 359, 360, 361, 362, 363 ], 'gender'] = 'male'
# artist.loc[[345, 357], 'gender'] = 'female'
# artist.loc[[346, 347, 349, 352, 353, 356,  ], 'gender'] = 'male, female'
# artist.loc[[305, 309, 310, 317, 318, 320, 322, 329, 330, 332, 333, 334, 335], 'gender'] = 'male'
# artist.loc[[294, 308, 319, 323  ], 'gender'] = 'female'
# artist.loc[[274, 286, 312], 'gender'] = 'male, female'
# artist.loc[300, ['members', 'birth_place', 'gender']] = ['Rudolf Schenker', 'Klaus Meine', 'Matthias Jabs', 
#                                                         'Paweł Mąciwoda', 'Mikkey Dee'], 'Germany', 'male'
# artist.loc[[273, 276, 281, 282, 283, 285, 287, 290, 291, 295, 297, 298], 'gender'] = 'male'
# artist.loc[294, 'gender'] = 'female'
# artist.loc[[274, 286 ], 'gender'] = 'male, female'
# artist.loc[[248, 249, 250, 251, 252, 254, 257, 260, 262, 263, 264, 265, 267, 268, 271], 'gender'] = 'male'
# artist.loc[[222, 224, 225, 226, 227, 228, 229, 230, 233, 234, 235, 236, 240, 242, 243, 245], 'gender'] = 'male'
# artist.loc[[178, 179,181, 183, 189, 191, 192, 193, 194, 195, 208, 211, 216, 217, 219, 221], 'gender'] = 'male'
# artist.loc[203, 'gender'] = 'male, female'
# artist.loc[[141, 145, 146, 147, 155, 158, 160, 161, 162, 164, 170, 177 ], 'gender'] = 'male'
# artist.loc[[139, 143, 144, 159, 163, 168,   ], 'gender'] = 'female'
# artist.loc[175, 'gender'] = 'male, female'
# artist.loc[[82, 88, 89, 90, 96, 108, 112, 113, 120, 129, 134, 135, 136, 137, 138], 'gender'] = 'male'
# artist.loc[[87, 92, 132], 'gender'] = 'female'
# artist.loc[[122, 125], 'gender'] = 'male, female'
# artist.loc[[82, 83, 84, 85, 86,  ], 'gender'] = 'male'
# artist.loc[[2094,2095], 'gender'] = 'female'
# artist.loc[[39, 43, 44, 45, 46, 47, 49, 52, 54, 62], 'gender'] = 'male'
# artist.loc[[64, 65, 66, 69, 70, 2100, 2101, 2102, 2104 ], 'gender'] = 'male'
# artist.loc[[74, 79, 80 ], 'gender'] = 'male'
# artist.loc[[2096, 2098, 2099 ], 'gender'] = 'female'
# artist.loc[[71, 73 ], 'gender'] = 'male, female'

# %%
artist.to_csv('artists_details_with_id_gender.csv', index=False)

# %%
# country = coco.convert(element, to='name_short')
# import country_converter as coco
