# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs
import time
from tqdm import tqdm
from multiprocessing.dummy import Pool as ThreadPool
import random
from itertools import cycle
from requests.auth import HTTPProxyAuth
import unicodedata
import re

# %% [markdown]
# Component C:
#
# Lyrics scraping from Musixmatch.com

# %% [markdown]
# Step1:
# Use ready csv file with list of artists and songs that need to be scraped
# Use own list of proxies to avoid ban by musixmatch.com
# Use own list of user agents to avoid ban by musixmatch.com

# %%
CSV_FILE_NAME = 'track_artist_audio_features_cleaned.csv'
PROXIES = 'proxies.txt'
USER_AGENT = 'user_agents.txt'

# Getting list of proxies (purchased from webshare.com)
with open(PROXIES, 'r') as f: 
    list_proxy = f.read().splitlines()

with open(USER_AGENT, 'r') as f:
    user_agents = f.read().splitlines()

# %% [markdown]
# Step2:
# Preprocess song/artist names, so that they can be used for musixmatch URL generation

# %%
def process_str(str):
  '''
  Removes all the special characters from the string, such as $, --
  '''
  
  return str.replace('--', '').replace("'", '').replace('(', '') \
          .replace(')', '').replace('.', '').replace('!','') \
          .replace('/', '-').replace('[', '').replace(']', '') \
          .replace(',', '').replace('"', '').replace('*', '') \
          .replace('$', '-')

def slugify(value, allow_unicode=False):
    '''
    Formats the string to be suitable for naming .txt file
    Convert to ASCII. 
    Convert spaces or repeated dashes to single dashes. 
    Remove characters that aren't alphanumerics,
    underscores, or hyphens. Convert to lowercase. 
    Strips leading and trailing whitespace, dashes, and underscores.
    '''
    value = str(value)
    if allow_unicode:
        value = unicodedata.normalize('NFKC', value)
    else:
        value = unicodedata.normalize('NFKD', value).encode('ascii', 'ignore').decode('ascii')
    value = re.sub(r'[^\w\s-]', '', value.lower())
    return re.sub(r'[-\s]+', '-', value).strip('-_')

def get_lyrics(data):
  '''
  Accepts list containing artist_name and song
  Creates multiple threads
  Initiates web scraping
  Displays data retrieving completion status
  Returns lyrics of this song retrieved from musixmatch.com

  '''
  lyrics = []

  def return_music_info(data):
    '''
    Helper function to utilize multithreading and display progress in real time using tqdm and imap

    '''
    artist_name, song = data
    sleep_interval = (4 + 2 * random.random()) # random float number between 1 and 3
    time.sleep(sleep_interval) # random pause to avoid IP banning by website
    output = [song, artist_name, scrape_lyrics(artist_name, song)]
    return output

  pool = ThreadPool(20) # 20 threads to speed up the process
  lyrics = tqdm(pool.imap(return_music_info, data), total=len(data)) #display progress of process

  return lyrics


def write_to_file(lyrics, song_name, artist_name):
    '''
    Accepts lyrics (str), song_name (str), artist_name (str)
    Writes lyrics to .txt file

    '''
    with open(slugify(f'{song_name} - {artist_name}') + '.txt', 'w', encoding="utf-8-sig") as f:
        f.writelines(lyrics)

def write_failed(song_name, artist_name):
    '''
    Accepts lyrics (str), song_name (str), artist_name (str)
    Writes lyrics which could not be retrieved to .txt file

    '''
    with open(f'__failed__.txt', 'a', encoding="utf-8-sig") as f:
        f.write(f'{song_name} - {artist_name}\n')


error_artist = []

def scrape_lyrics(artist_name, song):
  '''
  Accepts artist name and song
  Scrapes musixmatch website
  Returns lyrics of given (artist, song)

  '''

  song = process_str(song)
  artist_name = process_str(artist_name)
  url = f'https://www.musixmatch.com/lyrics/{artist_name}/{song}'
  headers = {'User-Agent': random.choice(user_agents)} #imitating real browser request. randomly selected browser agent

  proxy_data = random.choice(list_proxy) #take random proxy from the list
  proxy = ':'.join(proxy_data.split(':')[:2]) #retract proxy
  username, password = proxy_data.split(':')[2], proxy_data.split(':')[3] #retract username, password
  proxies = {
      "http": 'http://' + proxy,
    }
  auth = HTTPProxyAuth(username, password)
  r = requests.post(url, headers=headers, proxies=proxies, auth=auth)
  if r:
      
    soup = bs(r.content, 'html5lib') #getting webpage content using BeautifulSoup and html5lib decoding 
    lyrics_parts = soup.select('.mxm-lyrics__content ') #selecting lyrics parts from webpage 

    #join parts of lyrics
    result = []
    for part in lyrics_parts:   
      result.append(part.text)
    lyrics = ' '.join(result)
    
    #writing lyrics into separate file
    if lyrics:
      write_to_file(lyrics, song, artist_name)
    else:
      print('Warning! No lyrics!', url)
      write_failed(song, artist_name)

    return lyrics
    
  else:
    print('Error! ', r.status_code, artist_name, song)
    error_artist.append((artist_name, song))


def get_songs_data(csv_file_name):
  '''
  Generates list of [artist, song] pairs from the csv file
  '''

  data_list = []
  
  df = pd.read_csv(csv_file_name) #reading song name, artist from the csv file
  
  for i in range(len(df)):
    artist_name = df.loc[i]['artist_name'].casefold().replace(' ', '-')
    song = df.loc[i]['song'].casefold().replace(' ', '-')   
    
    data_list.append([artist_name, song])

  return data_list

# %%
# This cell initiates the whole lyrics scraping process and gets the lyrics from musixmatch.com
# All the lyrics are going to be saved on your device in separate .txt files
# You can get blocked by the musixmatch.com after several requests
# To stop the process press RESTART on the toolbar
data = get_songs_data(CSV_FILE_NAME)
get_lyrics(data)
# Out:
#   0%|          | 0/7669 [00:00<?, ?it/s]
# Warning! No lyrics! https://www.musixmatch.com/lyrics/thomas-rhett/life-changes
# Warning! No lyrics! https://www.musixmatch.com/lyrics/taylor-swift/we-are-never-ever-getting-back-together
# Warning! No lyrics! https://www.musixmatch.com/lyrics/taylor-swift/bad-blood
# Warning! No lyrics! https://www.musixmatch.com/lyrics/maroon-5/sugar
# Warning! No lyrics! https://www.musixmatch.com/lyrics/bruno-mars/24k-magic
# Warning! No lyrics! https://www.musixmatch.com/lyrics/bruno-mars/thats-what-i-like
# Warning! No lyrics! https://www.musixmatch.com/lyrics/r-kelly/ignition-remix
# Warning! No lyrics! https://www.musixmatch.com/lyrics/ed-sheeran/photograph
# Warning! No lyrics! https://www.musixmatch.com/lyrics/neon-trees/everybody-talks
# Warning! No lyrics! https://www.musixmatch.com/lyrics/ed-sheeran/galway-girl
# Warning! No lyrics! https://www.musixmatch.com/lyrics/taylor-swift/wildest-dreams-taylors-version
# Warning! No lyrics! https://www.musixmatch.com/lyrics/khalid/young-dumb-&-broke
# Warning! No lyrics! https://www.musixmatch.com/lyrics/ed-sheeran/thinking-out-loud
# Warning! No lyrics! https://www.musixmatch.com/lyrics/billboard-top-100-hits/steal-my-girl
# Warning! No lyrics! https://www.musixmatch.com/lyrics/sugarland/stuck-like-glue
# Warning! No lyrics!Warning! No lyrics! https://www.musixmatch.com/lyrics/tom-petty/free-fallin
#  https://www.musixmatch.com/lyrics/bill-conti/gonna-fly-now-theme-from-rocky---remastered-2006
# Warning! No lyrics! https://www.musixmatch.com/lyrics/natasha-bedingfield/unwritten
# Warning! No lyrics! https://www.musixmatch.com/lyrics/taylor-swift/ready-for-it?
# Warning! No lyrics! https://www.musixmatch.com/lyrics/bruno-mars/when-i-was-your-man
# Warning! No lyrics! https://www.musixmatch.com/lyrics/katy-perry/roar
# Warning! No lyrics!Warning! No lyrics! https://www.musixmatch.com/lyrics/portugal-the-man/feel-it-still
#  https://www.musixmatch.com/lyrics/train/hey-soul-sister
# Warning! No lyrics! https://www.musixmatch.com/lyrics/taylor-swift/i-knew-you-were-trouble
# Warning! No lyrics! https://www.musixmatch.com/lyrics/taylor-swift/blank-space
# Warning! No lyrics! https://www.musixmatch.com/lyrics/van-morrison/brown-eyed-girl
# Warning! No lyrics! https://www.musixmatch.com/lyrics/taylor-swift/you-belong-with-me-taylor’s-version
# Warning! No lyrics! https://www.musixmatch.com/lyrics/the-killers/all-these-things-that-ive-done
# Warning! No lyrics! https://www.musixmatch.com/lyrics/justin-timberlake/feel-it-still
# Warning! No lyrics! https://www.musixmatch.com/lyrics/taylor-swift/hey-stephen-taylor’s-version
# Warning! No lyrics! https://www.musixmatch.com/lyrics/jason-derulo/it-girl
# Warning! No lyrics! https://www.musixmatch.com/lyrics/carly-rae-jepsen/call-me-maybe
# Warning! No lyrics! https://www.musixmatch.com/lyrics/taylor-swift/22-taylors-version
# Warning! No lyrics! https://www.musixmatch.com/lyrics/dnce/cake-by-the-ocean
# Warning! No lyrics! https://www.musixmatch.com/lyrics/village-people/ymca
# Warning! No lyrics! https://www.musixmatch.com/lyrics/taylor-swift/shake-it-off
# Warning! No lyrics!Warning! No lyrics! https://www.musixmatch.com/lyrics/taylor-swift/welcome-to-new-york
# Warning! No lyrics! https://www.musixmatch.com/lyrics/taylor-swift/our-song
#  https://www.musixmatch.com/lyrics/taylor-swift/style
# Warning! No lyrics! https://www.musixmatch.com/lyrics/taylor-swift/love-story
# Warning! No lyrics! https://www.musixmatch.com/lyrics/sam-smith/stay-with-me
# Warning! No lyrics! https://www.musixmatch.com/lyrics/loose-passenger-seat/let-her-go
# Warning! No lyrics! https://www.musixmatch.com/lyrics/justin-timberlake/mirrors
# Warning! No lyrics! https://www.musixmatch.com/lyrics/taylor-swift/gorgeous
# Warning! No lyrics! https://www.musixmatch.com/lyrics/taylor-swift/mean
# Warning! No lyrics! https://www.musixmatch.com/lyrics/ed-sheeran/the-a-team
# Warning! No lyrics! https://www.musixmatch.com/lyrics/demi-lovato/sorry-not-sorry
# Warning! No lyrics! https://www.musixmatch.com/lyrics/katy-perry/firework
# Warning! No lyrics! https://www.musixmatch.com/lyrics/jordan-davis/singles-you-up
# Warning! No lyrics! https://www.musixmatch.com/lyrics/john-legend/all-of-me
# Warning! No lyrics!Warning! No lyrics! https://www.musixmatch.com/lyrics/taylor-swift/teardrops-on-my-guitar-radio-single-remix
#  https://www.musixmatch.com/lyrics/ed-sheeran/perfect
# Warning! No lyrics! https://www.musixmatch.com/lyrics/kelly-clarkson/stronger-what-doesnt-kill-you
# Warning! No lyrics! https://www.musixmatch.com/lyrics/brett-young/in-case-you-didnt-know
# Warning! No lyrics! https://www.musixmatch.com/lyrics/devin-dawson/all-on-me
# Warning! No lyrics! https://www.musixmatch.com/lyrics/justin-bieber/what-do-you-mean?
# Warning! No lyrics! https://www.musixmatch.com/lyrics/thomas-rhett/unforgettable
# Warning! No lyrics! https://www.musixmatch.com/lyrics/luke-bryan/light-it-up
# Warning! No lyrics! https://www.musixmatch.com/lyrics/blake-shelton/unforgettable
# Warning! No lyrics! https://www.musixmatch.com/lyrics/lanco/greatest-love-story
# Warning! No lyrics! https://www.musixmatch.com/lyrics/brett-young/like-i-loved-you
# Warning! No lyrics! https://www.musixmatch.com/lyrics/walker-hayes/you-broke-up-with-me
# Warning! No lyrics! https://www.musixmatch.com/lyrics/brett-kissel/we-were-that-song
# Warning! No lyrics! https://www.musixmatch.com/lyrics/brett-eldredge/the-long-way
# Warning! No lyrics! https://www.musixmatch.com/lyrics/morgan-evans/kiss-somebody
# Warning! No lyrics! https://www.musixmatch.com/lyrics/thomas-rhett/marry-me
# Warning! No lyrics! https://www.musixmatch.com/lyrics/iyaz/replay
# Warning! No lyrics! https://www.musixmatch.com/lyrics/billy-currington/do-i-make-you-wanna
# Warning! No lyrics! https://www.musixmatch.com/lyrics/granger-smith/happens-like-that
# Warning! No lyrics! https://www.musixmatch.com/lyrics/jason-derulo/trumpets
# Warning! No lyrics! https://www.musixmatch.com/lyrics/outkast-tribute-band/hey-ya
# Warning! No lyrics! https://www.musixmatch.com/lyrics/miley-cyrus/wrecking-ball
# Warning! No lyrics! https://www.musixmatch.com/lyrics/jackie-lee/getting-over-you
